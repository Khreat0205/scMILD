# %%
import sys, os
sys.path.append(r"src")

import train_scMILD

# %%
train_scMILD.train_scMILD(data_dir='data/Lupus',dataset="Lupus",device_num=0,data_dim=3000, mil_latent_dim=16, student_batch_size=256, teacher_learning_rate=1e-4, student_learning_rate=1e-4, encoder_learning_rate=1e-4,
                 scMILD_epoch=500, scMILD_neg_weight=0.1, scMILD_stuOpt=1, scMILD_patience=15, val_combined_metric=True, add_suffix="_0604_lupus_test_444_opgmm", 
                 n_exp=8, exp=None, gmm=True)
# Out:
# INFO: Using device: cuda:0
# Experiment 1
# Training:   0%|          | 0/500 [00:00<?, ?it/s]
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# gmm converged
# ...

# %%
# import torch
# from src.dataset import MilDataset, InstanceDataset, collate, update_instance_labels_with_bag_labels
# train_dataset = torch.load('data/Lupus/train_dataset_exp2.pt', map_location='cuda:0')
# train_dataset = torch.load('/home/local/kyeonghunjeong_920205/nipa_bu/COVID19/3.analysis/9.MIL/ProtoCell4P-main/data/lupus/disease/train_dataset_exp1.pt')
# train_dataset = torch.load('/home/local/kyeonghunjeong_920205/nipa_bu/COVID19/3.analysis/9.MIL/ProtoCell4P-main/data/lupus/disease/train_dataset_exp1_HVG_count_noflt.pt')
# train_dataset = torch.load('/home/local/kyeonghunjeong_920205/nipa_bu/COVID19/3.analysis/9.MIL/ProtoCell4P-main/data/lupus/disease/train_dataset_exp1_HVG_count.pt')
